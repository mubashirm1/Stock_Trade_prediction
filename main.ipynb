# %%
import  import_ipynb
import pandas as pd
from module import metric_analysis_functions as maf

# %%
#historical price action data, metric data  and coresponding signal 
required_object = maf(start_date = '2022-12-21',end_date = '2024-09-30',interval = '1d')
data = required_object.all_data(moving_average =False,
                           bolliger_band= False,
                           CCI  =True,
                           signal=True,
                           moving_average_window= 50,
                           bollinger_band_window= 20,
                           CII_window = 20)
data.dropna().head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2022-12-23 00:00:00+00:00  87.776001  87.984001  87.638000  87.776001
# 2022-12-26 00:00:00+00:00  86.906097  86.910103  86.906097  87.802002
# 2022-12-27 00:00:00+00:00  86.910103  88.299004  86.904099  86.910103
# 2022-12-28 00:00:00+00:00  88.024002  88.290001  87.759003  88.031998
# 2022-12-29 00:00:00+00:00  87.774002  88.331001  87.768997  87.774002
#
#                                  CCI signal_CCI
# Date
# 2022-12-23 00:00:00+00:00  74.086694    Neutral
# 2022-12-26 00:00:00+00:00  33.332114    Neutral
# 2022-12-27 00:00:00+00:00  38.469539    Neutral
# 2022-12-28 00:00:00+00:00  81.715637    Neutral
# 2022-12-29 00:00:00+00:00  73.174548    Neutral

# %%
#Candle Stick chart 
required_object.candle_stick_chart(moving_average =False,
                           bolliger_band= False,
                           CCI  =True,
                           signal=True,
                           moving_average_window= 50,
                           bollinger_band_window= 20,
                           CII_window = 20)
